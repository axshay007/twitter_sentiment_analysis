# %% [markdown]
# <a href="https://colab.research.google.com/github/axshay007/twitter_sentiment_analysis/blob/main/twitter_sentiment_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U IPython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install vaex
import vaex
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %%time
df = vaex.open('/content/training.1600000.processed.noemoticon.csv')
# Out:
# CPU times: user 197 ms, sys: 31.7 ms, total: 229 ms
# Wall time: 128 ms

# %%
df = pd.read_csv('/content/training.1600000.processed.noemoticon.csv',encoding = 'latin',header=None)
df.head()
# Out:
#    0           1                             2         3                4  \
# 0  0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                    5
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
import pandas as pd
import numpy as np

# %%
df.columns = ['sentiment', 'id', 'date', 'query', 'user_id', 'text']
df.head(10)
# Out:
#    sentiment          id                          date     query  \
# 0          0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 5          0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
# 6          0  1467811592  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 7          0  1467811594  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 8          0  1467811795  Mon Apr 06 22:20:05 PDT 2009  NO_QUERY
# 9          0  1467812025  Mon Apr 06 22:20:09 PDT 2009  NO_QUERY
#
#            user_id                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# ...

# %%
df.shape
# Out:
# (1600000, 6)

# %%
x = df.drop(['sentiment','query'], axis=1, inplace=True)

# %%
y=df['sentiment']
